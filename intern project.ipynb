# %%
from google.colab import drive
drive.mount('/content/drive')

root = "drive/My Drive/"
file0 = '0.csv'
file1 = '1.csv'
file2 = '2.csv'
file3 = '3.csv'
file4 = '4.csv'

def read_line(filepath):
  file = open(filepath, 'r')
  lines = []

  while True:
    line = file.readline()
    if not line:
      break
    lines.append(line)

  return lines
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
lines0 = read_line(root + file0)
lines1 = read_line(root + file1)
lines2 = read_line(root + file2)
lines3 = read_line(root + file3)
lines4 = read_line(root + file4)

y = []
x = []

for line in lines0[1:]:
  feature = []
  elements = line.split(',')
  y.append(elements[1])
  for item in elements[2:]:
    feature.append(item)
  feature[-1] = feature[-1].replace('\n', '')
  x.append(feature)

for line in lines1[1:]:
  feature = []
  elements = line.split(',')
  y.append(elements[1])
  for item in elements[2:]:
    feature.append(item)
  feature[-1] = feature[-1].replace('\n', '')
  x.append(feature)

# for line in lines2[1:]:
#   feature = []
#   elements = line.split(',')
#   y.append(elements[1])
#   for item in elements[2:]:
#     feature.append(item)
#   feature[-1] = feature[-1].replace('\n', '')
#   x.append(feature)

for line in lines3[1:]:
  feature = []
  elements = line.split(',')
  y.append(elements[1])
  for item in elements[2:]:
    feature.append(item)
  feature[-1] = feature[-1].replace('\n', '')
  x.append(feature)

for line in lines4[1:]:
  feature = []
  elements = line.split(',')
  y.append(elements[1])
  for item in elements[2:]:
    feature.append(item)
  feature[-1] = feature[-1].replace('\n', '')
  x.append(feature)

print(len(y))
print(x[:5])

for i in range(len(y)):
  y[i] = float(y[i])

for i in range(len(x)):
  for j in range(len(x[i])):
    x[i][j] = float(x[i][j])

print(x[:5])

x1 = []
x2 = []
x3 = []
x4 = []
x5 = []
x6 = []
x7 = []
x8 = []
x9 = []
x10 = []
x11 = []
x12 = []
x13 = []
x14 = []
x15 = []
x16 = []

for i in range(len(x)):
  for j in range(len(x[i])):
    if j == 0:
      x1.append(x[i][j])
    if j == 1:
      x2.append(x[i][j])
    if j == 2:
      x3.append(x[i][j])
    if j == 3:
      x4.append(x[i][j])
    if j == 4:
      x5.append(x[i][j])
    if j == 5:
      x6.append(x[i][j])
    if j == 6:
      x7.append(x[i][j])
    if j == 7:
      x8.append(x[i][j])
    if j == 8:
      x9.append(x[i][j])
    if j == 9:
      x10.append(x[i][j])
    if j == 10:
      x11.append(x[i][j])
    if j == 11:
      x12.append(x[i][j])
    if j == 12:
      x13.append(x[i][j])
    if j == 13:
      x14.append(x[i][j])
    if j == 14:
      x15.append(x[i][j])
    if j == 15:
      x16.append(x[i][j])

x_ax = range(len(y))
plt.scatter(x_ax,x1,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x1')

plt.show()

plt.scatter(x_ax,x2,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x2')

plt.show()

plt.scatter(x_ax,x3,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x3')

plt.show()

plt.scatter(x_ax,x4,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x4')

plt.show()

plt.scatter(x_ax,x5,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x5')

plt.show()

plt.scatter(x_ax,x6,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x6')

plt.show()

plt.scatter(x_ax,x7,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x7')

plt.show()

plt.scatter(x_ax,x8,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x8')

plt.show()
  
plt.scatter(x_ax,x9,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x9')

plt.show()

plt.scatter(x_ax,x10,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x10')

plt.show()

plt.scatter(x_ax,x11,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x11')

plt.show()

plt.scatter(x_ax,x12,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x12')

plt.show()

plt.scatter(x_ax,x13,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x13')

plt.show()

plt.scatter(x_ax,x14,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x14')

plt.show()

plt.scatter(x_ax,x15,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x15')

plt.show()

plt.scatter(x_ax,x16,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x16')

plt.show()
# Out:
# 398328
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
#Gaussian: x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13
def normalization(data):
    _range = np.max(abs(data))
    return data / _range



x1 = normalization(np.array(x1)).tolist()
x2 = normalization(np.array(x2)).tolist()
x3 = normalization(np.array(x3)).tolist()
x4 = normalization(np.array(x4)).tolist()
x5 = normalization(np.array(x5)).tolist()
x6 = normalization(np.array(x6)).tolist()
x7 = normalization(np.array(x7)).tolist()
x8 = normalization(np.array(x8)).tolist()
x9 = normalization(np.array(x9)).tolist()
x10 = normalization(np.array(x10)).tolist()
x11 = normalization(np.array(x11)).tolist()
x12 = normalization(np.array(x12)).tolist()
x13 = normalization(np.array(x13)).tolist()

plt.scatter(x_ax,x1,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x1')

plt.show()

plt.scatter(x_ax,x2,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x2')

plt.show()

plt.scatter(x_ax,x3,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x3')

plt.show()

plt.scatter(x_ax,x4,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x4')

plt.show()

plt.scatter(x_ax,x5,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x5')

plt.show()

plt.scatter(x_ax,x6,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x6')

plt.show()

plt.scatter(x_ax,x7,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x7')

plt.show()

plt.scatter(x_ax,x8,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x8')

plt.show()
  
plt.scatter(x_ax,x9,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x9')

plt.show()

plt.scatter(x_ax,x10,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x10')

plt.show()

plt.scatter(x_ax,x11,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x11')

plt.show()

plt.scatter(x_ax,x12,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x12')

plt.show()

plt.scatter(x_ax,x13,color='black')
plt.legend()

plt.xlabel('number')
plt.ylabel('x13')

plt.show()
train_data = []
for i in range(len(y)):
  feature = []
  feature.append(x1[i])
  feature.append(x2[i])
  feature.append(x3[i])
  feature.append(x4[i])
  feature.append(x5[i])
  feature.append(x6[i])
  feature.append(x7[i])
  feature.append(x8[i])
  feature.append(x9[i])
  feature.append(x10[i])
  feature.append(x11[i])
  feature.append(x12[i])
  feature.append(x13[i])
  train_data.append(feature)

features = tf.convert_to_tensor(train_data)
labels = tf.convert_to_tensor(y)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
features = tf.convert_to_tensor(train_data[:350000])
labels = tf.convert_to_tensor(y[:350000])

model = keras.Sequential([
    keras.layers.Dense(128),
    keras.layers.Dense(1)
])


sgd = tf.keras.optimizers.SGD(lr=0.001)

model.compile(optimizer=sgd,
              loss='mean_squared_error')


model.fit(features, labels, epochs=10)
# Out:
# Epoch 1/10
# 10938/10938 [==============================] - 9s 858us/step - loss: 0.0011
# Epoch 2/10
# 10938/10938 [==============================] - 10s 870us/step - loss: 4.5994e-04
# Epoch 3/10
# 10938/10938 [==============================] - 9s 862us/step - loss: 2.8467e-04
# Epoch 4/10
# 10938/10938 [==============================] - 9s 862us/step - loss: 1.9444e-04
# Epoch 5/10
# 10938/10938 [==============================] - 11s 1ms/step - loss: 1.4167e-04
# Epoch 6/10
# 10938/10938 [==============================] - 12s 1ms/step - loss: 1.0797e-04
# Epoch 7/10
# 10938/10938 [==============================] - 10s 944us/step - loss: 8.5085e-05
# Epoch 8/10
# 10938/10938 [==============================] - 9s 839us/step - loss: 6.8866e-05
# Epoch 9/10
# 10938/10938 [==============================] - 9s 837us/step - loss: 5.7013e-05
# Epoch 10/10
# 10938/10938 [==============================] - 9s 845us/step - loss: 4.8136e-05

# %%
weights = model.weights
history = model.history
print(history.history['loss'])
loss = history.history['loss']
epochs = range(len(loss))
plt.figure()
plt.plot(epochs, loss)
plt.title('loss vs. epochs of training dataset')
plt.xlabel("Epoch")
plt.ylabel("loss")
plt.show()
# Out:
# [0.0010847068624570966, 0.0004599354288075119, 0.00028466901858337224, 0.00019444125064183027, 0.0001416653540218249, 0.00010797376307891682, 8.508493920089677e-05, 6.886611663503572e-05, 5.7013439800357446e-05, 4.813623309019022e-05]

# %%
print('lines0', len(lines0))
print('lines1', len(lines1))
# print('lines2', len(lines2))
print('lines3', len(lines3))
print('lines4', len(lines4))

test_features = tf.convert_to_tensor(train_data[350001:])
test_labels = tf.convert_to_tensor(y[350001:])
results = model.evaluate(test_features, test_labels)
# Out:
# lines0 99583
# lines1 99583
# lines3 99583
# lines4 99583
# 1511/1511 [==============================] - 1s 779us/step - loss: 8.6681e-05
